# %% [markdown]
# <a href="https://colab.research.google.com/github/asrianda/latAlgoritma/blob/main/lat2/mat2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,3,4,7,8,9])
y=np.array([2,3,4,6,7,10])
plt.plot(x,y,marker='o',mfc='r')
plt.title('PT ABC')
plt.xlabel('Penjualan')
plt.ylabel('Tahun')
plt.show()
